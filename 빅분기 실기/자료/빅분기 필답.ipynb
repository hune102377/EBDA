# %%
import random
import pandas as pd

quiz_list = pd.read_excel('./빅분기_실기_단답형_대비.xlsx', )
quiz_list['기출 여부']=quiz_list['기출 여부'].fillna(0)
quiz_list=quiz_list.dropna()
quiz_num = range(quiz_list.shape[0])

def print_quize(i):
  unknown= 0
  if(quiz_list.iloc[i,2] == 1):
    print("-----------기출-----------")
  print('문제', i,)
  print(quiz_list.iloc[i,0])
  x = input()
  if x == '?':
      unknown = 1
  print('정답 : ', quiz_list.iloc[i,1], '\n')
  return(unknown, x)

def study_hard(mode = 'random'):
  unknown = 0
  unknown_quiz = []
  if mode =='random' : 
    while 1 :
      unknown_quiz = []
      selected_quize = random.sample(quiz_num, 10)
      
      for i in range(10):
        q_num = selected_quize[i]
        result, x = print_quize(q_num)
        if x =='x':
          break;
        unknown = unknown + result
        if result == 1:
          unknown_quiz.append(q_num)

      
      if len(unknown_quiz) != 0 :
        print("?수 : ", unknown)
        print("-----------? 문제 ---------")
        for num in unknown_quiz:
          print_quize(num)
      print("\nx를 눌러 조의를 표하시오")
      x = input()
      if x =='x':
        break;

  if mode == 'all':
    unknown_quiz = []
        
    selected_quize = random.sample(quiz_num, len(quiz_list))
    for i in range(len(selected_quize)):
      q_num = selected_quize[i]
      result, x = print_quize(q_num)
      if result == 1:
        unknown_quiz.append(q_num)
      if x =='x':
        break;

    if len(unknown_quiz) != 0 :
      print("?수 : ", unknown)
      print("-----------? 문제 ---------")
      for num in unknown_quiz:
        print_quize(num)

# %%
study_hard()
# Out:
# 문제 193
# 변수들의 자기상관성을 기반으로 한 시계열 모형으로 현시점의 자료를 p시점 전의 과거 자 료를 통해 설명할 수 있는 모델이다. 자기 자신의 과거 값이 이후 자신의 값에 영향을 준다. / 현시점의 자료가 k 시점 이전의 유한개의 과거 자료로 설명할 수 있는 모형 / 자기 자신 의 과거 값이 이후 자신의 값에 영향을 주기 때문에 이름이 붙음
# 정답 :  자기회귀모형(AutoRegressive,AR모형)
#
# 문제 188
# 풀어야 할 문제에 대한 상세한 설명 및 해당 문제를 해결했을 때 발생하는 효과를 명시함으 로써 향후 데이터 분석 문제로의 전환 및 적합성 평가에 활용하도록 하는 것은 무엇인가?
# 정답 :  분석 유스 케이스
#
# 문제 96
# 평균으로부터 K*표준편차만큼 떨어져 있는 값들을 이상값으로 판단하는 방법
# 정답 :  ESD(Extreme Studentized Deviation)
#
# 문제 128
# 하나 이상의 변수에 대해서 변수 사이의 차이와 유사성 등을 표현하는 방법
# 정답 :  비교 시각화
#
# 문제 26
# 전산시스템을 필요로 하는 곳으로부터 하청을 받아 시스템의 기획 개발, 유지보수, 운영 등 을 대신해주는 업종
# 정답 :  SI(System Integration, 시스템 구축)
#
# 문제 57
# 표본을 조사하여 얻은 데이터로 표본의 특징을 수치화한 값 /
# 모수를 추정하기 위해 구하는 표본 값들에대한 용어
# 정답 :  통계량
#
# 문제 105
# 크기가 같은 표본을 여러 번 단순임의 복원 추출하여 분류기를 생선한 후 앙상블하는 기법 / 모델의 안정성을 높이기 위하여 분석 데이터로부터 여러 개의 단순 복원 임의 추출하여 다수결을 통해 최종의 예측 모델을 도출하는 알고리즘 / 각각의 분류기가 모두 같은 유형의 알고리즘 기반이지만, 데이터 샘플링을 서로 다르게 가져가면서 학습을 수행해 보팅을 수행 하는 것
# 정답 :  배깅
#
# 문제 79
# 인공신경망은 노드에 입력되는 값을 바로 다음 노드로 전달하지 않고 비선형 함수에 통과시킨 후
# 전달하는데 이때 사용되는 비선형 함수를 무엇이라고 하는가?
# 정답 :  활성화 함수
#
# 문제 182
# 지역별 매출액, 영업이익률, 판매량과 같이 수치로 명확하게 표현되는 데이터로, 그 양이 크 게 증가하더라도 이를 DBMS에 저장, 검색, 분석하여 활용하기가 용이하다.
# 정답 :  정량적 데이터
#
# 문제 103
# 의사결정 나무에서 더 이상 분기되지 않도록 하는 규칙은?
# 정답 :  정지규칙
#
# ?수 :  1
# -----------? 문제 ---------
# 문제 193
# 변수들의 자기상관성을 기반으로 한 시계열 모형으로 현시점의 자료를 p시점 전의 과거 자 료를 통해 설명할 수 있는 모델이다. 자기 자신의 과거 값이 이후 자신의 값에 영향을 준다. / 현시점의 자료가 k 시점 이전의 유한개의 과거 자료로 설명할 수 있는 모형 / 자기 자신 의 과거 값이 이후 자신의 값에 영향을 주기 때문에 이름이 붙음
# 정답 :  자기회귀모형(AutoRegressive,AR모형)
#
#
# x를 눌러 조의를 표하시오
# 문제 34
# 여러 변수의 변량을 서로 상관성이 높은 변수들의 선형 조합으로 만든 새로운 변수로 요약 및 축소하는 기법
# 정답 :  PCA(Principal Components Analysis)
#
# 문제 9
# 이것은 인공지능의 한 분야로 간주된다. 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술 을 개발하는 분야이다. /
# 학습 데이터로 학습한 알려진 특성을 활용해 ‘예측’하는 방법
# 정답 :  머신러닝
#
# 문제 176
# 새로운 모델을 만들 시, 기존의 만들어진 모델을 사용하여 학습을 빠르게 하며, 모델 성능을 높이는 방법은?
# 정답 :  전이학습
#
# 문제 48
# 데이터를 이해하고 의미 있는 관계를 찾아내기 위해 데이터의 통곗값과 분포 등을 시각화하고 분석하는 것
# 정답 :  EDA(Exploratory Data Analysis)
#
# 문제 136
# 데이터 안에 관찰할 수 없는 잠재적인 변수가 존재한다고 가정하는 차원축소기법. 모형을 세운 뒤 관찰 가능한 데이터를 이용하여 해당 잠재 요인을 도출하고 데이터 안의 구조를 해석하는 기법은?
# 정답 :  요인분석
#
# 문제 104
# 여러 개의 결정 트리 분류기(같은 알고리즘이 여러 개)가 전체 데이터에서 배깅 방식으로 각자의 데이터를 샘플링해 개별적으로 학습을 한 뒤 최종적으로 모든 분류기가 보팅을 통해 예측을 결정하는 앙상블 알고리즘은?
# 정답 :  랜덤 포레스트
#
# 문제 167
# 통계적 추정을 할 때 표본자료 중 모집단에 대한 정보를 주는 독립적인 자료의 수
# 정답 :  자유도
#
# 문제 130
# 고정된 훈련 데이터 세트와 테스트 검증데이터 세트로 평가하여 반복적으로 튜닝할 시
# 테스트 데이터에 과적합되는 결과가 생기는 것을 방지하는 방법
# 정답 :  교차 검증
#
# 문제 57
# 표본을 조사하여 얻은 데이터로 표본의 특징을 수치화한 값 /
# 모수를 추정하기 위해 구하는 표본 값들에대한 용어
# 정답 :  통계량
#
# 문제 169
# 성능이 약한 학습기를 여러 개 연결하여 순차적으로 학습하여, 정답을 맞히지 못한 부분에 가중치를 부여함으로써 강한 학습기를 생성하는 앙상블 기법 / 모델의 정확성을 높이기 위해 오분류된 개체들에 가중치를 부여함으로써 새로운 분류규칙을 생성 및 반복하여 약한 분류 모델을 강한 분류모델로 변형하는 알고리즘
# 정답 :  부스팅
#
#
# x를 눌러 조의를 표하시오
# 문제 124
# 데이터의 전부 또는 일부분을 대체값(공백, 노이즈 등)으로 변환하는 비식별화 방법 / 개인의 사생활 침해를 방지하고 통계 응답자의 비밀사항은 보호하면서 통계자료의 유용성을 최 대한 확보할 수 있는 데이터 변환 방법은?
# 정답 :  데이터 마스킹
#
# 문제 120
# 문제 정의 자체가 어려운 경우 데이터 기반으로 문제의 재정의 및 해결방안을 탐색하고 이를 지속적으로 개선하는 방식
# 정답 :  상향식 접근 방식
#
# 문제 66
# 귀무가설이 참일 때 귀무가설을 기각하는 오류
# 정답 :  1종 오류(알파 오류)
#
# 문제 184
# 시계열 분석의 기본이 되는 중요한 개념으로 시계열의 평균과 분산이 일정하고 일정한 추세 가 없는 것을 무엇이라 하는가?
# 정답 :  정상 시계열
#
# 문제 148
# 번호를 부여한 샘플을 나열하여 k개씩 n개의 구간을 나누고 첫 구간에서 하나를 임의로 선택한 후에
# k개씩 띄어서 표본을 선택하고 매번 k번째 항목을 추출하는 표본 추출 방법
# 정답 :  계통추출방법
#
# 문제 84
# 실제 Positive인 값 중 Positive로 분류한 비율
# 정답 :  재현율, 민감도, 참 긍정률
#
# 문제 14
# 여러 사람이 공유하여 사용할 목적으로 체계화해 통합, 관리하는 데이터의 집합 /
# 데이터를 받아들이고 저장, 공급하기 위하여 일정한 구조에 따라서 편성된 데이터의 집합
# 정답 :  데이터베이스
#
# 문제 47
# 기존 변수들을 조합하여 새롭게 만들어진 변수
# 정답 :  파생변수
#
# 문제 179
# 총 평균과 각 집단의 평균 차이에 의해 생긴 집단 간 분산 비율을 나타내는 분포
# 정답 :  F-분포
#
# 문제 211
# 새로운 모델을 만들 시, 기존의 만들어진 모델을 사용하여 학습을 빠르게 하며, 모델 성능을 높이는 방법은?
# 정답 :  전이학습
#
#
# x를 눌러 조의를 표하시오
# 문제 98
# 비선형적인 관계도 파악할 수 있는 상관계수는?
# 정답 :  스피어만 상관계수
#
# 문제 31
# 고정된 필드에 저장되어 있지는 않지만, 데이터와 메타데이터, 스키마 등을 포함하는 데이터 (XML, HTML, JSON 등). 규칙을 가지고 있어 필요 시 정형 데이터로 변형 가능
# 정답 :  반정형 데이터
#
# 문제 140
# 분산 환경에서 대량의 로그 데이터를 효과적으로 수집하여 합친 후 다른 곳으로 전송할 수 있는 신뢰할 수 lT는 서비스
# 정답 :  Apache Flume (플럼)
#
# 문제 39
# 동일한 데이터셋에서 일반적인 데이터 값의 범위를 벗어난 값
# 정답 :  이상값
#
# 문제 54
# 구조화되어 있지 않은 문서를 단어로 나누는 과정
# 정답 :  토큰화
#
# 문제 103
# 의사결정 나무에서 더 이상 분기되지 않도록 하는 규칙은?
# 정답 :  정지규칙
#
# 문제 206
# 과대 적합을 방지하기 위해 인공지능 학습 과정에서 일부 신경망 일부만 동작하고 일부는 동작하지 않도록 하는 방법
# 정답 :  드롭아웃
#
# 문제 65
# 귀무가설 분포에서 검정통계량보다 극단적인 값이 관측될 확률값.
# 이 값이 작을수록 검정통 계량이 귀무가설의 내용에 적합하지 않음을 나타낸다.
# 정답 :  유의 확률(P-value)
#
# 문제 159
# 현재 데이터가 과거 백색잡음의 선형 가중합으로 구성된다는 모형 / 시간이 갈수록 관측치의 평균값이 지속해서 증가하거나 감소하는 시계열모형 / 백색잡음 과정은 서로 독립이고 평균이 0인 확률변수이므로 항상 정상성을 만족함
# 정답 :  이동평균모형(Moving Average,MA모형)
#
# 문제 116
# 당사자의 동의 없는 개인정보 수집 및 활용하거나 제3자에게 제공하는 것을 금지하는 등
# 개인정보보호를 강화한 내용을 담아 제정한 법률
# 정답 :  개인정보보호법
#
#
# x를 눌러 조의를 표하시오
# 문제 145
# 주어진 데이터를 k개의 클러스터로 묶는 알고리즘으로, 각 클러스터와 거리 차이의 분산을 최소화하는 방식으로 동작한다. 자율 학습의 일종으로, 레이블이 달려 있지 않은 입력 데이터에 레이블을 달아주는 역할을 수행한다.
# 정답 :  k-평균 군집화 알고리즘
#
# 문제 182
# 지역별 매출액, 영업이익률, 판매량과 같이 수치로 명확하게 표현되는 데이터로, 그 양이 크 게 증가하더라도 이를 DBMS에 저장, 검색, 분석하여 활용하기가 용이하다.
# 정답 :  정량적 데이터
#
# 문제 160
# 데이터가 비정상성이 아닌 증거를 나타내는 경우에 적용되며, 초기 차분 단계(모델의 "통합된" 부분에 해당)를 한 번 이상 적용하여 비정상성을 제거할 수 있다. / 분기, 반기, 연간 단위로 다음 지표를 예측하거나 주간, 월간 단위로 지표를 리뷰하여 경향을 분석하는 기법
# 정답 :  자기회귀누적 이동평균모형(AutoRegressive Integrated Moving Average, ARIMA모형)
#
# 문제 101
# 현 시점의 자료값에서 전 시점의 자료를 빼는 방법은?
# 정답 :  차분
#
# 문제 199
# 데이터의 결측값(치)을 채우거나 이상값을 제거하여 데이터 품질을 높이는 과정
# 정답 :  데이터 정제
#
# 문제 106
# 다층 신경망에서 은닉층이 많아 학습이 이루어지지 않는 문제는 무엇인가?
# 정답 :  기울기 소실 문제
#
# 문제 53
# 자연어 분석 작업의 대상이 되는 대량의 텍스트 문서들을 모아놓은 집합
# 정답 :  말뭉치
#
# 문제 64
# 통계적인 가설검정에서 사용되는 기준값으로 α로 표시
# 정답 :  유의수준
#
# 문제 140
# 분산 환경에서 대량의 로그 데이터를 효과적으로 수집하여 합친 후 다른 곳으로 전송할 수 있는 신뢰할 수 lT는 서비스
# 정답 :  Apache Flume (플럼)
#
# 문제 178
# 정규 분포의 평균을 측정할 때 주로 사용되는 분포로 모집단의 분산(혹은 표준편차)이
# 알려져 있지 않은 경우에 정규분포 대신 이용하는 확률분포는?
# 정답 :  t-분포
#
#
# x를 눌러 조의를 표하시오
# 문제 193
# 변수들의 자기상관성을 기반으로 한 시계열 모형으로 현시점의 자료를 p시점 전의 과거 자 료를 통해 설명할 수 있는 모델이다. 자기 자신의 과거 값이 이후 자신의 값에 영향을 준다. / 현시점의 자료가 k 시점 이전의 유한개의 과거 자료로 설명할 수 있는 모형 / 자기 자신 의 과거 값이 이후 자신의 값에 영향을 주기 때문에 이름이 붙음
# 정답 :  자기회귀모형(AutoRegressive,AR모형)
#
# 문제 156
# 이것은 비즈니스 측면에서 일반적으로 ‘공동 활용의 목적으로 구축된 유무형의 구조물’을 의미한다. 수집된 데이터를 가공, 처리, 저장해두고 이 데이터에 접근할 수 있도록 API를 공개 한다. 그러면 다양한 서드파티 사업자들이 비즈니스에 필요한 정보를 추출해 활용하게 되고 빅데이터는 그 자체로 이 역할을 수행하게 된다.
# 정답 :  플랫폼
#
# 문제 16
# 사용자의 의사결정에 도움을 주기 위해 수집된 대량의 비즈니스 데이터베이스 /
# 기업의 의사결정 과정을 지원하기 위한 주제 중심적으로 통합적이며 시간성을 가지는 비휘발성 데이터의 집합
# 정답 :  데이터 웨어하우스(Data Warehouse, DW)
#
# 문제 65
# 귀무가설 분포에서 검정통계량보다 극단적인 값이 관측될 확률값.
# 이 값이 작을수록 검정통 계량이 귀무가설의 내용에 적합하지 않음을 나타낸다.
# 정답 :  유의 확률(P-value)
#
# 문제 168
# 시계열에 영향을 주는 일반적인 요인을 시계열에서 분리해 분석하는 방법 /
# 분석목적에 따라 특정 요인만 분리 분석하거나 제거하는 작업을 함
# 정답 :  분해시계열
#
# 문제 118
# 사생활 침해를 방지하기 위해 데이터에 포함된 개인정보를 삭제하거나 알아볼 수 없는 형태로 변환하는 방법
# 정답 :  익명화
#
# 문제 98
# 비선형적인 관계도 파악할 수 있는 상관계수는?
# 정답 :  스피어만 상관계수
#
# 문제 9
# 이것은 인공지능의 한 분야로 간주된다. 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술 을 개발하는 분야이다. /
# 학습 데이터로 학습한 알려진 특성을 활용해 ‘예측’하는 방법
# 정답 :  머신러닝
#
# 문제 83
# Positive로 예측한 것 중에서 실제 값이 Positive인 비율

# %%
study_hard('all')
# Out:
# 문제 82
# 전체 데이터에서 올바르게 분류한 데이터의 비율
# 정분류율
# 정답 :  정확도
#
# 문제 63
# 가설 검정에서 사용된 샘플 데이터로부터 계산된 표본 통계량. 이것으로 P-value를 계산하 며 귀무가설을 기각할 것인지 판별하며
# 검정통계량
# 정답 :  검정통계량
#
# 문제 97
# 주어진 시간 또는 영역에서 어떤 사건의 발생 횟수를 나타내는 확률 분포는?
# 포아송
# 정답 :  포아송분포
#
# 문제 108
# 군집내 거리와 군집간의 거리를 기준으로 군집 분할 성과를 측정하는 방식은? / 군집 내의 데이터 응집도와 군집 간 분리도를 계산하는 지표는?
# 실루엣계수
# 정답 :  실루엣 계수
#
# 문제 147
# 지역별 매출액, 영업이익률, 판매량과 같이 수치로 명확하게 표현되는 데이터로, 그 양이 크 게 증가하더라도 이를 DBMS에 저장, 검색, 분석하여 활용하기가 용이하다.
# 정형데이터
# 정답 :  정량적 데이터
#
# 문제 110
# 계층적 군집분석에서 군집 내의 오차제곱합에 기초하여 거리를 측정하는 방법은? / 오차제 곱합의 합에 비해 증가한 정도가 작아지는 방향으로 군집하는 방법은?
# ?
# 정답 :  와드연결법
#
# 문제 139
# RDBMS와 하둡 사이의 데이터를 이동시켜주는 애플리케이션
# ?
# 정답 :  Apache Sqoop (스쿱)
#
# 문제 1
# 추론과 추정의 근거를 이루는 객관적 사실 / 현실에서 관찰하거나 측정하여 수집한 사실
# 데이터
# 정답 :  데이터
#
# 문제 150
# 베이즈 정리와 특징에 대한 조건부 독립을 가설로 하는 알고리즘으로 클래스에 대한 사전 정보와 데이터로부터 추출된 정보를 결합하고 베이즈 정리를 이용하여 어떤 데이터가 특정 클래스에 속하는지를 분류하는 알고리즘
# 나이브 베이즈 분류기
# 정답 :  나이브 베이즈 분류
#
# 문제 154
# 의사결정나무 중 연속형 타깃변수(또는 목표변수)를 예측하는 의사결정나무를 무엇이라고 하 는가?
# ?
# 정답 :  회귀나무
#
# 문제 3
# 데이터를 통해 도출된 다양한 정보를 구조화하여 유의미한 정보를 분류하고 개인적인 경험 을 결합해 내재화한 것
# 지식
# 정답 :  지식
#
# 문제 165
# 데이터의 결측값을 처리하는 방법 중 이것은 보통 m번 대체를 수행하고 그에 따른 m개의 자료가 생성되면 이를 각각 분석하는 방법이다.
# ?
# 정답 :  다중 대체법
#
# 문제 105
# 크기가 같은 표본을 여러 번 단순임의 복원 추출하여 분류기를 생선한 후 앙상블하는 기법 / 모델의 안정성을 높이기 위하여 분석 데이터로부터 여러 개의 단순 복원 임의 추출하여 다수결을 통해 최종의 예측 모델을 도출하는 알고리즘 / 각각의 분류기가 모두 같은 유형의 알고리즘 기반이지만, 데이터 샘플링을 서로 다르게 가져가면서 학습을 수행해 보팅을 수행 하는 것
# 보팅
# 정답 :  배깅
#
# 문제 43
# 변수를 연속적으로 추가 혹은 제거하면서 AIC가 낮아지는 모델을 찾는 방법
# 단계적 선택법
# 정답 :  단계적 방법
#
# 문제 162
# K-익명성의 동질설 문제나 배경지식을 이용하는 문제를 해결하기 위하여 익명성을 향상시키 는 방법
# ?
# 정답 :  L-다양성
#
# 문제 164
# 데이터의 결측값(치)을 채우거나 이상값을 제거하여 데이터 품질을 높이는 과정
# 데이터 정제
# 정답 :  데이터 정제
#
# 문제 22
# 직무에 특정한 구체적인 기술이며, 실제로 업무를 수행하는 데 필요한 기술
# BI
# 정답 :  하드 스킬
#
# 문제 141
# 빅데이터 저장 기술로 컴퓨터 네트워크를 통해 공유하는 여러 호스트 컴퓨터의 파일에 접근 할 수 있게 하는 파일 시스템은?
# 클라우드
# 정답 :  분산 파일 시스템
#
# 문제 13
# 오피니언 리더, 즉 영향력 있는 사람을 찾아낼 수 있으며, 고객 간 소셜 관계를 파악
# 소셜 네트워크 분석
# 정답 :  소셜 네트워크 분석
#
# 문제 125
# 주어진 각 개체들의 유사성을 분석해서 높은 대상끼리 일반화된 그룹으로 분류하는 기법
# 분류
# 정답 :  군집분석
#
# 문제 153
# 풀어야 할 문제에 대한 상세한 설명 및 해당 문제를 해결했을 때 발생하는 효과를 명시함으 로써 향후 데이터 분석 문제로의 전환 및 적합성 평가에 활용하도록 하는 것은 무엇인가?
# 분석 유즈케이스
# 정답 :  분석 유스 케이스
#
# 문제 159
# 현재 데이터가 과거 백색잡음의 선형 가중합으로 구성된다는 모형 / 시간이 갈수록 관측치 의 평균값이 지속해서 증가하거나 감소하는 시계열모형 / 백색잡음 과정은 서로 독립이고 평균이 0인 확률변수이므로 항상 정상성을 만족함
# MA 모형
# 정답 :  이동평균모형(Moving Average,MA모형)
#
# 문제 27
# 정답이 있는 데이터를 활용하여 분석 모델을 학습시키는 것 / 레이블이 범주형인 분류와 연 속형인 회귀로 나뉜다.
# 지도학습
# 정답 :  지도 학습
#
# 문제 80
# 코호넨 맵이라고도 불리며, 인공신경망을 기반으로 차원축소와 군집화를 동시에 수행할 수 있는 알고리즘은? / 코호넨에 의해 제시되었으며, 비지도 신경망으로 고차원의 데이터를 이 해하기 쉬운 저차원의 뉴런으로 정렬하여 지도의 형태로 형상화하는 클러스터링 방법은 무 엇인가?
# som
# 정답 :  자기조직화지도 (SOM, Self Organizing Maps)
#
# 문제 6
# 고객의 대규모 거래데이터로부터 함께 구매가 발생하는 규칙을 도출하여, 고객이 특정 상품 구매 시 이와 연관성 높은 상품을 추천하는 분석 / 어떤 변인 간에 주목할 만한 상관관계가 있는지를 찾아내는 방법
# 연관분석
# 정답 :  연관규칙  분석(장바 구니분석)
#
# 문제 128
# 하나 이상의 변수에 대해서 변수 사이의 차이와 유사성 등을 표현하는 방법
# ?
# 정답 :  비교 시각화
#
# 문제 91
# 데이터에 관한 구조화된 데이터 / 어떤 목적을 가지고 만들어진 데이터 / 데이터 그 자체가 아니라, 자료의 속성, 구조 등을 설명하는 데이터
# ?
# 정답 :  메타데이터
#
# 문제 156
# 이것은 비즈니스 측면에서 일반적으로 ‘공동 활용의 목적으로 구축된 유무형의 구조물’을 의 미한다. 수집된 데이터를 가공, 처리, 저장해두고 이 데이터에 접근할 수 있도록 API를 공개 한다. 그러면 다양한 서드파티 사업자들이 비즈니스에 필요한 정보를 추출해 활용하게 되고 빅데이터는 그 자체로 이 역할을 수행하게 된다.
# 플랫폼
# 정답 :  플랫폼
#
# 문제 4
# 지식의 축적과 아이디어가 결합된 창의적 산물
# 지혜
# 정답 :  지혜
#
# 문제 29
# 웹을 운영하는 주체가 누구나 사용할 수 있게 공개한 데이터를 개발자나 사용자가 수집해 사용하는 기술을 의미
# API
# 정답 :  Open API (Application Programming Interface)
#
# 문제 130
# 고정된 훈련 데이터 세트와 테스트 검증데이터 세트로 평가하여 반복적으로 튜닝할 시 테스트 데이터에 과적합되는 결과가 생기는 것을 방지하는 방법
# 홀드 아웃
# 정답 :  교차 검증
#
# 문제 62
# 실험, 연구를 통해 증명하고자 하는 새로운 아이디어 혹은 가설
# 대립가설
# 정답 :  대립가설
#
# 문제 174
# 다양한 데이터를 통합적으로 분석하여 기업 의사결정권자가 합리적인 의사결정이 가능하도 록 지원하는 일련의 활동
# ?
# 정답 :  BI(Business Intelligence)
#
# 문제 8
# 최적화가 필요한 문제의 해결책을 자연 선택, 돌연변이 등과 같은 매커니즘을 통해 점진적 으로 진화시키는 방법
# 유전자 알고리즘
# 정답 :  유전 알고리즘
#
# 문제 51
# 데이터가 분포의 중심에 어느 정도 몰려 있는가를 측정할 때 사용하는 척도
# 분산
# 정답 :  첨도
#
# 문제 177
# 인간의 간섭을 가능한 최소한으로 하여 금융 서비스나 투자 관리를 온라인으로 제공하는 투 자 자문역할의 일종이다. 수리적 규칙이나 알고리즘에 기반한 디지털 금융 서비스를 제공한 다.
# ?
# 정답 :  로보 어드바이저(Robo Advisor)
#
# 문제 160
# 데이터가 비정상성이 아닌 증거를 나타내는 경우에 적용되며, 초기 차분 단계(모델의 "통합 된" 부분에 해당)를 한 번 이상 적용하여 비정상성을 제거할 수 있다. / 분기 , 반기, 연간 단위로 다음 지표를 예측하거나 주간, 월간 단위로 지표를 리뷰하여 경향을 분석하는 기법
# x
# 정답 :  자기회귀누적 이동평균모형(AutoRegressive Integrated Moving Average, ARIMA모형)
#
# ?수 :  0
# -----------? 문제 ---------
# 문제 110
# 계층적 군집분석에서 군집 내의 오차제곱합에 기초하여 거리를 측정하는 방법은? / 오차제 곱합의 합에 비해 증가한 정도가 작아지는 방향으로 군집하는 방법은?
# 와드연결법
# 정답 :  와드연결법
#
# 문제 139
# RDBMS와 하둡 사이의 데이터를 이동시켜주는 애플리케이션
# 스쿱
# 정답 :  Apache Sqoop (스쿱)
#
# 문제 154
# 의사결정나무 중 연속형 타깃변수(또는 목표변수)를 예측하는 의사결정나무를 무엇이라고 하 는가?
# 회귀나무
# 정답 :  회귀나무
#
# 문제 165
# 데이터의 결측값을 처리하는 방법 중 이것은 보통 m번 대체를 수행하고 그에 따른 m개의 자료가 생성되면 이를 각각 분석하는 방법이다.
# 다중대치법
# 정답 :  다중 대체법
#
# 문제 162
# K-익명성의 동질설 문제나 배경지식을 이용하는 문제를 해결하기 위하여 익명성을 향상시키 는 방법
# m-다양성
# 정답 :  L-다양성
#
# 문제 128
# 하나 이상의 변수에 대해서 변수 사이의 차이와 유사성 등을 표현하는 방법
# 변수 시각화
# 정답 :  비교 시각화
#
# 문제 91
# 데이터에 관한 구조화된 데이터 / 어떤 목적을 가지고 만들어진 데이터 / 데이터 그 자체가 아니라, 자료의 속성, 구조 등을 설명하는 데이터
# 메타데이터
# 정답 :  메타데이터
#
# 문제 174
# 다양한 데이터를 통합적으로 분석하여 기업 의사결정권자가 합리적인 의사결정이 가능하도 록 지원하는 일련의 활동
# bi
# 정답 :  BI(Business Intelligence)
#
# 문제 177
# 인간의 간섭을 가능한 최소한으로 하여 금융 서비스나 투자 관리를 온라인으로 제공하는 투 자 자문역할의 일종이다. 수리적 규칙이나 알고리즘에 기반한 디지털 금융 서비스를 제공한 다.
# 로보 어드바이저
# 정답 :  로보 어드바이저(Robo Advisor)
